# %% [markdown]
# # Анализ unit-экономики приложения Procrastinate Pro+
# ## Инструкция по выполнению проекта:
#
# Я - аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев бизнес был убыточен - инвестирование в привлечение пользователей оказалось неэффективным. Необходимо понять причины произошедшего.
#
# Есть логи сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Нужно изучить поведение пользователей: когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# ### Шаг 1. Загрузка данных и подготовка их к анализу
# Загрузим данные о визитах, заказах и расходах в переменные. Оптимизируем данные для анализа. Убедимся, что тип данных в каждой колонке — правильный.
#
# ### Шаг 2. Задание функций для расчета и анализа LTV, ROI, удержания и конверсии
#
# Для расчёта и анализа показателей unit-экономики лучше использовать функции.
#
# ### Шаг 3. Проведите исследовательский анализ данных
#
# Подготовим профили пользователей и минимальную и максимальную дату их привлечения.
#
# Изучим:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?
#
# ### Шаг 4. Маркетинг
# Изучим:
#
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# ### Шаг 5. Окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишием проблемы, с которыми мы столкнулись:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Необходимо описать возможные причины обнаруженных проблем и подготовить рекомендации для рекламного отдела. При решении этого шага будем считать, что мы наблюдаем данные с 1-го ноября 2019 года и что в вашей организации окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
#
# ### Шаг 6. Выводы
# - Какие основные причины неэффективности привлечения пользователей?
# - Что порекомендовать для отдела маркетинга для повышения эффективности?
#
#
# ### Описание данных
# Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):
#
# `User Id` — уникальный идентификатор пользователя
# `Device` — категория устройства пользователя
# `Session start` — дата и время начала сессии
# `Session End` — дата и время окончания сессии
# `Channel` — идентификатор рекламного источника, из которого пришел пользователь
# `Region` - страна пользователя
#
# Таблица `orders_log_short` (информация о заказах):
#
# `User Id` — уникальный id пользователя, который сделал заказ
# `Event Dt` — дата и время покупки
# `Revenue` — выручка
#
# Таблица `costs_short` (информация о затратах на маркетинг):
#
# `Channel` — идентификатор рекламного источника
# `Dt` — дата
# `Costs` — затраты на этот рекламный источник в этот день

# %% [markdown]
# # Описание проекта "Анализ маркетинговой деятельности  Procrastinate Pro+"
# Компания направляет из бюджета солидное финансирование на привлечение новых клиентов и удержание старых, но терпит убытки.
#
# Моя задача в качестве маркетингового аналитика провести исследование маркетинговой деятельности компании, найти утечки бюджета и возможные зоны роста.
#
# В моём распоряжении есть данные о визитах пользователей (откуда, с какого устройства и по какому каналу зашёл пользователь), заказах (какие клиенты совершили транзакцию, когда и в каком объёме) и затраты на маркетинг (на продвижение какого канала, когда и в каком объёме произошло финансирование).
#
# Чтобы выполнить мою задачу мне предстоит:
# * провести загрузку данных
# * провести первичный анализ данных (изучить типы данных, проверить их на наличие пропусков и дубликатов)
# * определить функции для работы
# * подготовить профили клиентов
# * рассмотреть подробнее их распределение по странам, устройствам, каналам привлечения
# * оценить общие затраты на маркетинг и отдельно на клиента и канал привлечения
# * оценить общую окупаемость маркетинговой кампании и в разбивках на регионы, устройства, каналы
# * обобщить полученную информацию и подготовить рекомендации для маркетологов или даже для CMO

# %% [markdown]
# ## Шаг 1. Загрузите данные и подготовьте их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный.

# %% [markdown]
# ### Импорт библиотек и предварительный анализ
# Импортируем необходимые для работы библиотеки.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Откроем и взглянем на наши данные.

# %%
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),
    pd.read_csv('/datasets/orders_info_short.csv'),
    pd.read_csv('/datasets/costs_info_short.csv')
)

display(visits.head(), orders.head(), costs.head())
visits.info(), orders.info(), costs.info()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# Супер, пропусков у нас нет. Зато есть не змеиные названия столбцов и формат дат у нас `object`.

# %% [markdown]
# ### Подготовка данных

# %%
#мне чёт не очень хочется перебивать вручную все столбцы
for i in (visits, orders, costs):
    i.columns = i.columns.str.lower()
    i.columns = [j.replace(' ', '_') for j in i.columns]
    display(i.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# А теперь перегоним даты всех событий из `object` в `datetime64`.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Проверка на дубликаты

# %%
(visits.duplicated().value_counts(), 
 orders.duplicated().value_counts(), 
 costs.duplicated().value_counts())
# Out:
# (False    309901
#  dtype: int64,
#  False    40212
#  dtype: int64,
#  False    1800
#  dtype: int64)

# %% [markdown]
# Ни одного True по всем датафреймам. Победа!

# %% [markdown]
# ### Вывод
# Мы загрузили данные и увидели следующее:
# * названия столбцов все в разнобой - мы привели их к змеиному регистру
# * формат в столбцах с датой не тот, который нам нужен, и с которым удобно взаимодействовать - поменяли на `datetime`
# * метод .info() показал, что пропуски в данных отсутствуют - это хорошо
# * проверка на дубликаты ничего не дала

# %% [markdown]
# ## Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.

# %% [markdown]
# ### get_profiles()

# %%
# функция для создания пользовательских профилей

def get_profiles(
    visits, 
    orders, 
    costs
):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### get_retention()

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### get_conversion()

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### get_ltv()

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### plot_retention()

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### plot_conversion()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### plot_ltv_roi()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### filter_data()

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# Откроем профили пользователей с помощью функции `get_profiles()`.

# %% [markdown]
# ### Профили пользователей

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# ### Минимальная и максимальная даты привлечения. Момент и горизонт анализа.

# %% [markdown]
# Опредилим минимальную и максимальную дату привлечения пользователей.

# %%
min_date = profiles['first_ts'].dt.date.min()
max_date = profiles['first_ts'].dt.date.max()
min_date, max_date
# Out:
# (datetime.date(2019, 5, 1), datetime.date(2019, 10, 27))

# %% [markdown]
# Теперь для работы наших функций необходимо задать момент и горизонт анализа. По условию, у нас сегодня 1 ноября 2019 года *(эх, были времена)*, а горизонт анализа необходимо задать 14 дней.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# ### Распределение по странам

# %% [markdown]
# Нам необходимо прорабоать со странами, откуда приходят пользователи, посмотреть сколько из них переходят в статус покупателей и определить процент конверсии.

# %%
profiles_region = (profiles
                   .groupby('region')
                   .agg({'user_id': 'nunique'})
                  .merge(profiles
                         .query('payer == True')
                         .groupby('region')
                         .agg({'user_id': 'nunique'}), 
                         on=['region'])
                   .rename(columns={'user_id_x': 'total_visits', 
                                    'user_id_y': 'payers_visits'})
                  )
profiles_region['conversion, %'] = (profiles_region['payers_visits'] 
                                    / profiles_region['total_visits'] * 100).round(2)
profiles_region.sort_values(by='conversion, %', ascending=False)
# Out:
#                total_visits  payers_visits  conversion, %
# region
# United States        100002           6902           6.90
# Germany               14981            616           4.11
# UK                    17575            700           3.98
# France                17450            663           3.80

# %% [markdown]
# Пользователи из США явно больше остальных заинтересованы оформить платную подписку.

# %% [markdown]
# ### Распределение по устройствам

# %%
profiles_device = (profiles
                   .groupby('device')
                   .agg({'user_id': 'nunique'})
                  .merge(profiles
                         .query('payer == True')
                         .groupby('device')
                         .agg({'user_id': 'nunique'}), 
                         on=['device'])
                   .rename(columns={'user_id_x': 'total_visits', 
                                    'user_id_y': 'payers_visits'})
                  )
profiles_device['conversion, %'] = (profiles_device['payers_visits'] 
                                    / profiles_device['total_visits'] * 100).round(2)
profiles_device.sort_values(by='conversion, %', ascending=False)
# Out:
#          total_visits  payers_visits  conversion, %
# device
# Mac             30042           1912           6.36
# iPhone          54479           3382           6.21
# Android         35032           2050           5.85
# PC              30455           1537           5.05

# %% [markdown]
# ПК-бояре отстают в части конверсии от пользователей мобильных устройств и Мака.

# %% [markdown]
# ### Распределение по каналам привлечения

# %%
profiles_channel = (profiles
                   .groupby('channel')
                   .agg({'user_id': 'nunique'})
                  .merge(profiles
                         .query('payer == True')
                         .groupby('channel')
                         .agg({'user_id': 'nunique'}), 
                         on=['channel'])
                   .rename(columns={'user_id_x': 'total_visits', 
                                    'user_id_y': 'payers_visits'})
                  )
profiles_channel['conversion, %'] = (profiles_channel['payers_visits'] 
                                    / profiles_channel['total_visits'] * 100).round(2)
profiles_channel.sort_values(by='conversion, %', ascending=False)
# Out:
#                     total_visits  payers_visits  conversion, %
# channel
# FaceBoom                   29144           3557          12.20
# AdNonSense                  3880            440          11.34
# lambdaMediaAds              2149            225          10.47
# TipTop                     19561           1878           9.60
# RocketSuperAds              4448            352           7.91
# WahooNetBanner              8553            453           5.30
# YRabbit                     4312            165           3.83
# MediaTornado                4364            156           3.57
# LeapBob                     8553            262           3.06
# OppleCreativeMedia          8605            233           2.71
# organic                    56439           1160           2.06

# %% [markdown]
# Через `FaceBoom`, `AdNonSense` и `lambdaMediaAds` у нас конверсия свыше 10%, почти на этот показатель вышел `TipTop`. Остальные каналы на голову ниже в части конверсии пользователей в платящих клиентов.
#
# Конверсия `organic` ниже остальных каналов. Было бы удивительно, если конверсия какого-то канала была бы ниже.

# %% [markdown]
# ### Вывод
# Если мы хотим эффективно привлекать пользователей к совершению оплаты, то наиболее оптимальным выглядит следующий портрет клиента: американец, не использующий ПК, который пользуется `FaceBoom`, `AdNonSense` и `lambdaMediaAds`.

# %% [markdown]
# ## Шаг 4. Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# ### Оценка затрат
# Посчитаем общую стоимость затрат с начала мая 2019 и по конец октября 2019.

# %%
total_costs = costs['costs'].sum()
display(f'Всего на привлечение потратили {round(total_costs)} денег')
# Out:
# 'Всего на привлечение потратили 105497 денег'

# %% [markdown]
# Не хватает контекста, чтобы сделать какие-то выводы по абсолютному значению совершённых трат на рекламу. Посмотрим динамику затрат на привлечение клиентов.

# %%
plt.figure(figsize=(15,8))
plt.grid()
plt.title('Общая динамика затрат на привлечение')
plt.plot(costs.groupby('dt')['costs'].sum())
plt.show()

# %% [markdown]
# Ага, динамика положительная, значит с каждым месяцем бюджет на рекламу растёт. Также заметны пики в июне, июле и октябре. Наврняка какие-то рекламные кампании.
#
# Давайте посмотрим чуть подробнее, на какие каналы уходит наш рекламный бюджет.

# %%
plt.figure(figsize=(15,8))
plt.grid()
plt.title('Динамика затрат на привлечение по каналам')
sns.lineplot(data=costs, x='dt', y='costs', hue='channel')
# Out:
# <AxesSubplot:title={'center':'Динамика затрат на привлечение по каналам'}, xlabel='dt', ylabel='costs'>

# %% [markdown]
# Большая часть бюджета у нас идёт на `TipTop` и `FaceBoom`. Остальные каналы у нас где-то в районе плинтуса. Также колебания в этих двух каналах оказывают влияние и на весь бюджет. Бюджетообразующие каналы получаются. Но конверсия `TipTop` у нас явна не так хороша, как у `FaceBoom`, и уступает более, чем в 2 раза.

# %% [markdown]
# ### Стоимость привлечения покупателя, или `CAC`

# %% [markdown]
# Посчитаем `CAC` для компании в целом. Для этого найдём среднее значение затрат на привлечение по всем каналам, кроме `organic` для заплативших пользователей.

# %%
profiles.query('channel != "organic" & payer == True')['acquisition_cost'].mean()
# Out:
# 1.3474692632010883

# %% [markdown]
# Посмотрим же как затраты на привлечение распределяются по каналам.

# %%
channel_costs = (profiles
                 .query('payer == True')
                 .groupby('channel')
                 .agg({'acquisition_cost': 'sum', 'user_id': 'nunique'})
                 .rename(columns={'user_id': 'payers'}))
channel_costs['ratio, %'] = channel_costs['acquisition_cost'] / channel_costs['acquisition_cost'].sum() * 100
channel_costs
channel_costs.sort_values(by='ratio, %', ascending=False)
# Out:
#                     acquisition_cost  payers   ratio, %
# channel
# TipTop                   5232.035624    1878  50.289611
# FaceBoom                 3959.805291    3557  38.061107
# AdNonSense                444.892444     440   4.276245
# WahooNetBanner            272.061112     453   2.615014
# lambdaMediaAds            165.447552     225   1.590259
# RocketSuperAds            147.309385     352   1.415918
# OppleCreativeMedia         58.356318     233   0.560913
# LeapBob                    55.119071     262   0.529797
# YRabbit                    34.870741     165   0.335173
# MediaTornado               33.912643     156   0.325964
# organic                     0.000000    1160   0.000000

# %% [markdown]
# Больше половины всего бюджета пришлось на `TipTop`, 38% приходится на `FaceBoom`. Третье место едва превысило 4%. К такому неравномерному распределению бюджета стоит относиться крайне осторожно. В случае форс-мажора необходимо быть готовым к мобилизации финансовых и маркетиноговых ресурсов.

# %% [markdown]
# Чтобы посчитать `CAC`, необходимо просуммировать затраты по каждому каналу и разделить их на количество уникальных плательщиков.

# %%
cac = channel_costs['acquisition_cost'] / channel_costs['payers']
cac.sort_values(ascending=False)
# Out:
# channel
# TipTop                2.785961
# FaceBoom              1.113243
# AdNonSense            1.011119
# lambdaMediaAds        0.735322
# WahooNetBanner        0.600576
# RocketSuperAds        0.418493
# OppleCreativeMedia    0.250456
# MediaTornado          0.217389
# YRabbit               0.211338
# LeapBob               0.210378
# organic               0.000000
# dtype: float64

# %% [markdown]
# Так и есть, `TipTop` превосходит следующего за ним `FaceBoom` в 2,5 раза в стоимости привлечения пользователей. Наводит на размышления о целесообразности такого канала.

# %% [markdown]
# ### Вывод
# `TipTop` ест много денег. Мы потратили в 1,5 раза больше денег, чтобы привлечь в 1,5 раза меньше пользователей по сравнению с `FaceBoom`. Хм...

# %% [markdown]
# ## Шаг 5. Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Проанализируйте общую окупаемость рекламы

# %% [markdown]
# Построим графики:
# * `LTV` - life time value - значение выручки на каждого клиента;
# * его динамику;
# * динамику `CAC` - customer acquisition cost - динамику расходов на привлечения клиента;
# * `ROI` - return of investment - отношение `LTV` и `CAC`, показывающее эффективность наших вложений;
# * динамику этой эффективности
#
# Если у нас показатель `ROI` за 14 дней не будет выходить за 1, то это фиаско и наша рекламная кампания убыточна.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('channel != "organic"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = [],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days)

# %% [markdown]
# О, нет! За 14 дней наши затраты так и не отбились. Отметим ещё большой скачок стоимости привлечения клиентов в июне, что не особо помогло справить с резким спадом динамики `ROI` - лишь небольшой отскок, а потом продолжение тренда на снижение.
#
# Необходимо проверить три различных версии, где же у нас наиболее сильные просадки.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по устройствам

# %% [markdown]
# Посмотрим, что у нас за ситуация с разбивкой по устройствам.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('channel != "organic"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = ['device'],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days, 14)

# %% [markdown]
# Видно, что ПК менее прибыльны, чем остальные устройства. Однако по стоимости видно, ПК заметно ниже, чуть выше них Андроид, а привлечение пользователей техники Apple обходится дороже. Вероятно это связано с политикой именно самой корпорации Apple.
#
# Ну и видно, что ПК окупается через 11 дней, у Андроида по прошествии 14 дней окупаемость 90%, что же касается "яблочников", то они находятся на уровне 70% по прошествии 2 недель.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по странам

# %% [markdown]
# Проведём анализ окупаемости рекламы с разбивкой по странам.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('channel != "organic"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = ['region'],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days, 14)

# %% [markdown]
# Из 4 стран: США, Великобритания, Германия и Франция - у США довольно высокий уровень выручки, Германия и Великобритания примерно на одном уровне, а Франция чуть ниже. Но(!) уровень затрат на рекламу в Штатах - просто космический. Страны Европы идут намного ниже и ровнее по затратам.
#
# **А вот и панчлайн - в середине мая произошла смена курса с Европейского рынка на Американский.**
#
# Реклама в странах Европы отбивается всего через 4-5 дней, а США не выходит в плюс даже за две недели. Учитывая колоссальный уровень затрат на США, необходимо пересмотреть маркетинговую кампанию в этом регионе.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Посмотрим, что же у нас происходит по рекламным каналам.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('channel != "organic"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = ['channel'],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days, 14)

# %% [markdown]
# Необходимо обратить внимание на эффективность привлечения в следующих каналах: `OppleCreativeMedia`, `MediaTornado` и `LeapBob`, которые на динамике показывают ужасные показатели.
#
# Что же касается окупаемости, то можно выделить три ветки:
# * `TipTop`, `FaceBoom` и `AdNonSense` - каналы, которые не выходят на уровень окупаемости за 2 недели
# * `OppleCreativeMedia` и `WahooNetBanner` - каналы, которые окупаются за 4-5 дней
# * остальные каналы, сроки окупания которых составляют 1-2 дня, особенно перспективным кажется `YRabbit`, который показал просто бешенную динамику `ROI` в летние месяцы
#
# `TipTop` создаёт нам прям большую дыру в бюджете, но также необходимо посмотреть, что у нас не так происходит с `FaceBoom` и `AdNonSense`.

# %% [markdown]
# ### Анализ конверсии и удержания

# %% [markdown]
# #### Анализ по устройствам

# %%
conversion, conversion_grouped, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, 
    visits, 
    observation_date, 
    horizon_days, 
    dimensions = ['device']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Конверсия пользователей ПК явно ниже, чем на других устройствах, которые идут более-менее ровно, примерно на 20%.
#
# Удержание пользователей ПК немного выше, чем пользователей других устройств, но критичного ничего не выделяется.

# %% [markdown]
# #### Анализ по странам

# %%
conversion, conversion_grouped, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, 
    visits, 
    observation_date, 
    horizon_days, 
    dimensions = ['region']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Как уже было отмечено выше, с середины мая пошла агрессивная маркетинговая кампания с привлечением большого количества бюджета. Конверсия повысилась прям сильно и резко. Однако клиента в США не удаётся удержать.

# %% [markdown]
# #### Анализ по каналам продвижения

# %%
conversion, conversion_grouped, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, 
    visits, 
    observation_date, 
    horizon_days, 
    dimensions = ['channel']
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# `FaceBoom` и `AdNonSense` имеют наивысшую конверсию среди всех каналов.
#
# Но в то же время `FaceBoom` и `AdNonSense` ~~страдают от недержания~~ имеют достаточно низкий уровень удержания клиентов, что сказывается на уровне окупаемости.
#
# На мой взгляд, очень перспективно выглядит `lambdaMediaAds`: у канала третья конверсия, но в то же время у него нет жёстких просадок по удержанию.

# %% [markdown]
# ### Бонусный анализ
# Представим, что мы премиум подписчик канала Соловьёв Live, и представим, какой же была бы жизнь без США.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('region != "United States"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = [],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days)

# %% [markdown]
# На лицо явное оздоровление ситуации: нет скачка по затратам, а эффективность рекламы немного большим, чем 2 дня.
#
# А теперь проверим, права ли наша бабушка, которая говорит, что эти все `TipTop`'ы нам не нужны.

# %%
ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles.query('channel != "TipTop"'), 
                                                                      orders, 
                                                                      observation_date,
                                                                      horizon_days,
                                                                      dimensions = [],
                                                                      ignore_horizon=False)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon_days)

# %% [markdown]
# Слушайте бабушку и ваша реклама начнёт окупаться уже на 4 день!

# %% [markdown]
# ### Вывод
# Наша смена парадигмы в сторону США и уход от Европы оказался провальным. Эффективность наших вложений в этот регион изначально была невысокой, а мы начали туда ещё больше заливать.
#
# Что же касается каналов, то `TipTop`, на которые возлагались большие надежды, себя не оправдал. `FaceBoom` и `AdNonSense` тоже весьма спорные кандидаты - конверсия высокая, но удержание никакое. Я бы рассмотрел `lambdaMediaAds` в Европе и `YRabbit` в США в качестве оптимальной альтернативы.

# %% [markdown]
# ## Шаг 6. Напишите выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# ### Итоговые выводы
# Проведя исследование профилей пользователей и их поведения, можно сделать следующие выводы:
# * Наша реклама **не окупается!**
# * США хоть и приносит нам довольно много выручки, но затраты на рекламу довольно высокие, её эффективность крайне низкая и удержание пользователей много ниже, чем в Европе
# * Причина не в устройстве, хоть iPhone и Mac не достаточно окупаются (дело всё же в США, где традиционно iPhone и Mac превалируют)
# * `TipTop` - это огромная дыра в бюджете, хоть и клиенты удерживаются там сравнительно неплохо, чего нельзя сказать о `FaceBoom` и `AdNonSense`, которые и показывают хорошую конверсию, в то же время имеют низкий уровень удержания

# %% [markdown]
# ### Рекомендации для повышения эффективности
# 1. Пересмотреть географию рынка. Возможно, американскому пользователю чего-то не хватает в нашем приложении (может доставки?). Как альтернатива, рассмотреть возможность расширения рынка на страны Азии.
# 2. Пересмотреть условия взаимоотношений с `TipTop`, потому что сегмент довольно "вкусный", но не за такие деньги.
# 3. Разработать новую маркетинговую кампанию, направленную на повышение удержания пользователей в `FaceBoom` и `AdNonSense`
# 4. Использовать `lambdaMediaAds` в Европе и `YRabbit` в качестве основных каналов привлечения.
